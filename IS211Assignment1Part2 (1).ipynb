# %%
class Book:
    author = ""
    title = ""

# %%
class Book:
    author = ""
    title = ""

    def __init__(self, author, title):
        self.author = author
        self.title = title

# %%
class Book:
    author = ""
    title = ""

    def __init__(self, author, title):
        self.author = author
        self.title = title

    def display(self):
        print(f"{self.title}, written by {self.author}")

# %%
# Instantiate object 1
book1 = Book("J. K. Rowling", "Harry Potter and the Goblet of Fire")

# Instantiate object 2
book2 = Book("Walter Scott", "Ivanhoe: A Romance")

# Print both objects to the screen
book1.display()
book2.display()
# Out:
# Harry Potter and the Goblet of Fire, written by J. K. Rowling
# Ivanhoe: A Romance, written by Walter Scott

# %%
# !git status
# !git add IS211Assignment1Part2.pynb
# !git commit -m "Add Part 2 Book class implementation"
# !git push origin main
# Out:
#   Cell In[5], line 1
#     git status
#         ^
# SyntaxError: invalid syntax
